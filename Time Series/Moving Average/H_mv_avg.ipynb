# %% [markdown]
# Implementation of Load Forecasting(Hourly) using **Moving Average** Methods on **Hourly Data**

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5e1737a2-ab81-4f1c-935c-2b5812714663" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e1737a2-ab81-4f1c-935c-2b5812714663">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving H_load.csv to H_load.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['H_load.csv']))
plt.figure(figsize=(20,5))
plt.plot(df[:500], label='Load')
plt.legend(loc='upper left')
plt.xlabel("Hours")
plt.ylabel("Load")
plt.show()

# %%
def mv_avg (l,n=-1): 
    sum=0
    if n<=-0:
         return 0
    
    for i in range(n):
        sum+=l[i]
    return round(sum/n)

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
l=list(df['Load']) #converting into a list


l_mv_avg=[]
for n in range(len(l)):
  l_mv_avg.append(mv_avg(l,n))

# %%
plt.figure(figsize=(10,6))
plt.plot(l[0:250], label='Load')
plt.plot(l_mv_avg[0:250], label='Moving Average', color='Red')
plt.legend(loc='upper left')
plt.xlabel("Hours")
plt.ylabel("Load")
plt.show()

# %%
mape=mean_absolute_percentage_error(l, l_mv_avg)
print("Mean Absolute Error Percentage in Moving Average Method is ", round(mape,2),"%")
# Out:
# Mean Absolute Error Percentage in Moving Average Method is  31.02 %
