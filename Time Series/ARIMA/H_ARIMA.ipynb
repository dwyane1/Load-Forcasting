# %% [markdown]
# Implementation of  Load Forecasting(Hourly) using **ARIMA** model on **Hourly Data**

# %%
# !pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 1.5MB 2.6MB/s
# ...
#      |████████████████████████████████| 2.1MB 13.0MB/s
# ...
#      |████████████████████████████████| 8.7MB 24.6MB/s
# ...
#   Found existing installation: Cython 0.29.20
#     Uninstalling Cython-0.29.20:
#       Successfully uninstalled Cython-0.29.20
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
import csv
import math
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pmdarima
import random
import seaborn as sns
import statsmodels.tsa.stattools as ts
from pmdarima import auto_arima
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2777e932-520f-4de4-977a-6f7b18920c30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2777e932-520f-4de4-977a-6f7b18920c30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving load2.csv to load2.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['load2.csv']))

# %%
l1=list()
l2=list()

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train=df['hour0'].head(700)
test=df['hour0'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour1'].head(700)
test=df['hour1'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour2'].head(700)
test=df['hour2'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour3'].head(700)
test=df['hour3'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour4'].head(700)
test=df['hour4'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour5'].head(700)
test=df['hour5'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour6'].head(700)
test=df['hour6'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour7'].head(700)
test=df['hour7'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour8'].head(700)
test=df['hour8'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour9'].head(700)
test=df['hour9'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour10'].head(700)
test=df['hour10'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour11'].head(700)
test=df['hour11'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour12'].head(700)
test=df['hour12'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour13'].head(700)
test=df['hour13'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour14'].head(700)
test=df['hour14'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour15'].head(700)
test=df['hour15'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour16'].head(700)
test=df['hour16'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour17'].head(700)
test=df['hour17'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour18'].head(700)
test=df['hour18'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour19'].head(700)
test=df['hour19'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour20'].head(700)
test=df['hour20'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour21'].head(700)
test=df['hour21'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour22'].head(700)
test=df['hour22'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()

train=df['hour23'].head(700)
test=df['hour23'][700:]

Arima_model=auto_arima(train, start_p=0, start_q=0, max_p=8, max_q=8, start_P=0, start_Q=0, max_P=0, max_Q=0, m=1, seasonal=False, trace=True, d=pmdarima.arima.ndiffs(train), D=0, error_action='warn', suppress_warnings=True, random_state =1 , n_fits=1)

Arima_model.summary()

prediction=pd.DataFrame(Arima_model.predict(n_periods=29), index=test.index)
prediction.columns = ['Predicted_Load']

l1+=test.tolist()
l2+=prediction['Predicted_Load'].tolist()
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=12637.248, BIC=12646.348, Time=0.047 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=12524.109, BIC=12537.758, Time=0.058 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=12456.562, BIC=12470.211, Time=0.114 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=False]; AIC=12635.249, BIC=12639.799, Time=0.023 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=12421.841, BIC=12440.039, Time=0.640 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=12420.679, BIC=12443.427, Time=0.499 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=12496.178, BIC=12514.376, Time=0.125 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=12422.753, BIC=12450.050, Time=0.445 seconds
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=12420.024, BIC=12447.322, Time=1.156 seconds
# ...

# %%
l3=list()
l4=list()

for i in range(0,29):
    for j in range(0,23):
        l3.append(l1[j*29+i])
        l4.append(l2[j*29+i])

mape=mean_absolute_percentage_error(l3, l4)

mape

# %%
plt.figure(figsize=(25,11))
plt.plot(l3, label='test')
plt.plot(l4, label='prediction')
plt.xlim(300,706)
plt.legend(loc='upper left')
plt.show()
